# %% [markdown]
# 1. Visualise the missing values
# 2. Understanding the feautures more

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\Naim\Documents\Github\naukri_com-job_sample.csv')

# %%
df.head(4)
# Out:
#                                company  \
# 0                     MM Media Pvt Ltd
# 1                   find live infotech
# 2  Softtech Career Infosystem Pvt. Ltd
# 3               Onboard HRServices LLP
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
#
#                                    jobtitle  numberofpositions  \
# 0  Walkin Data Entry Operator (night Shift)                NaN
# 1        Work Based Onhome Based Part Time.               60.0
# 2                    Pl/sql Developer - SQL                NaN
# 3    Manager/ad/partner - Indirect Tax - CA                NaN
#
#                           payrate                   postdate site_name  \
# 0         1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000       NaN
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 3      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
#
#                                   skills                           uniq_id
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae

# %%
df.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id'],
#       dtype='object')

# %%
df.shape
# Out:
# (22000, 14)

# %%
count_missing=df.isnull().sum()
count_missing
# Out:
# company                    4
# education               1996
# experience                 4
# industry                   5
# jobdescription             4
# jobid                      0
# joblocation_address      501
# jobtitle                   0
# numberofpositions      17536
# payrate                   97
# postdate                  23
# site_name              18013
# skills                   528
# uniq_id                    0
# dtype: int64

# %%
percent_missing=count_missing * 100/len(df)
percent_missing
# Out:
# company                 0.018182
# education               9.072727
# experience              0.018182
# industry                0.022727
# jobdescription          0.018182
# jobid                   0.000000
# joblocation_address     2.277273
# jobtitle                0.000000
# numberofpositions      79.709091
# payrate                 0.440909
# postdate                0.104545
# site_name              81.877273
# skills                  2.400000
# uniq_id                 0.000000
# dtype: float64

# %%
missing_value_df=pd.DataFrame({'count_missing':count_missing, 'percent_missing':percent_missing})

# %%
missing_value_df.style.background_gradient(cmap='Spectral')
# Out:
# <style  type="text/css" >
# #T_86c47_row0_col0,#T_86c47_row0_col1,#T_86c47_row2_col0,#T_86c47_row2_col1,#T_86c47_row3_col0,#T_86c47_row3_col1,#T_86c47_row4_col0,#T_86c47_row4_col1,#T_86c47_row5_col0,#T_86c47_row5_col1,#T_86c47_row7_col0,#T_86c47_row7_col1,#T_86c47_row10_col0,#T_86c47_row10_col1,#T_86c47_row13_col0,#T_86c47_row13_col1{
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }#T_86c47_row1_col0,#T_86c47_row1_col1{
#             background-color:  #d8434e;
#             color:  #f1f1f1;
#         }#T_86c47_row6_col0,#T_86c47_row6_col1,#T_86c47_row12_col0,#T_86c47_row12_col1{
#             background-color:  #ad1246;
#             color:  #f1f1f1;
#         }#T_86c47_row8_col0,#T_86c47_row8_col1{
#             background-color:  #545ca8;
#             color:  #f1f1f1;
#         }#T_86c47_row9_col0,#T_86c47_row9_col1{
#             background-color:  #a00343;
#             color:  #f1f1f1;
#         }#T_86c47_row11_col0,#T_86c47_row11_col1{
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }</style><table id="T_86c47_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count_missing</th>        <th class="col_heading level0 col1" >percent_missing</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86c47_level0_row0" class="row_heading level0 row0" >company</th>
#                         <td id="T_86c47_row0_col0" class="data row0 col0" >4</td>
#                         <td id="T_86c47_row0_col1" class="data row0 col1" >0.018182</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row1" class="row_heading level0 row1" >education</th>
#                         <td id="T_86c47_row1_col0" class="data row1 col0" >1996</td>
#                         <td id="T_86c47_row1_col1" class="data row1 col1" >9.072727</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row2" class="row_heading level0 row2" >experience</th>
#                         <td id="T_86c47_row2_col0" class="data row2 col0" >4</td>
#                         <td id="T_86c47_row2_col1" class="data row2 col1" >0.018182</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row3" class="row_heading level0 row3" >industry</th>
#                         <td id="T_86c47_row3_col0" class="data row3 col0" >5</td>
#                         <td id="T_86c47_row3_col1" class="data row3 col1" >0.022727</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row4" class="row_heading level0 row4" >jobdescription</th>
#                         <td id="T_86c47_row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_86c47_row4_col1" class="data row4 col1" >0.018182</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row5" class="row_heading level0 row5" >jobid</th>
#                         <td id="T_86c47_row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_86c47_row5_col1" class="data row5 col1" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row6" class="row_heading level0 row6" >joblocation_address</th>
#                         <td id="T_86c47_row6_col0" class="data row6 col0" >501</td>
#                         <td id="T_86c47_row6_col1" class="data row6 col1" >2.277273</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row7" class="row_heading level0 row7" >jobtitle</th>
#                         <td id="T_86c47_row7_col0" class="data row7 col0" >0</td>
#                         <td id="T_86c47_row7_col1" class="data row7 col1" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row8" class="row_heading level0 row8" >numberofpositions</th>
#                         <td id="T_86c47_row8_col0" class="data row8 col0" >17536</td>
#                         <td id="T_86c47_row8_col1" class="data row8 col1" >79.709091</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row9" class="row_heading level0 row9" >payrate</th>
#                         <td id="T_86c47_row9_col0" class="data row9 col0" >97</td>
#                         <td id="T_86c47_row9_col1" class="data row9 col1" >0.440909</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row10" class="row_heading level0 row10" >postdate</th>
#                         <td id="T_86c47_row10_col0" class="data row10 col0" >23</td>
#                         <td id="T_86c47_row10_col1" class="data row10 col1" >0.104545</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row11" class="row_heading level0 row11" >site_name</th>
#                         <td id="T_86c47_row11_col0" class="data row11 col0" >18013</td>
#                         <td id="T_86c47_row11_col1" class="data row11 col1" >81.877273</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row12" class="row_heading level0 row12" >skills</th>
#                         <td id="T_86c47_row12_col0" class="data row12 col0" >528</td>
#                         <td id="T_86c47_row12_col1" class="data row12 col1" >2.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_86c47_level0_row13" class="row_heading level0 row13" >uniq_id</th>
#                         <td id="T_86c47_row13_col0" class="data row13 col0" >0</td>
#                         <td id="T_86c47_row13_col1" class="data row13 col1" >0.000000</td>
#             </tr>
#     </tbody></table>

# %%
df.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id'],
#       dtype='object')

# %%
for col in df.columns:
    print('{} has {} values'.format(col,df[col].nunique()))
# Out:
# company has 8469 values
# education has 2355 values
# experience has 147 values
# industry has 63 values
# jobdescription has 21063 values
# jobid has 21910 values
# joblocation_address has 2329 values
# jobtitle has 17564 values
# numberofpositions has 84 values
# payrate has 1848 values
# postdate has 4203 values
# site_name has 1 values
# skills has 45 values
# uniq_id has 22000 values

# %%
unique=[]
for col in df.columns:
    unique.append([col,df[col].nunique(),df[col].unique()])

# %%
unique_df=[[col,df[col].nunique(),df[col].unique()] for col in df.columns]

# %%
count_df=pd.DataFrame(unique_df, columns=['col_name','count','unique'])

# %%
count_df.style.background_gradient(cmap='Spectral')
# Out:
# <style  type="text/css" >
# #T_94ea3_row0_col1{
#             background-color:  #fed884;
#             color:  #000000;
#         }#T_94ea3_row1_col1,#T_94ea3_row6_col1{
#             background-color:  #d7414e;
#             color:  #f1f1f1;
#         }#T_94ea3_row2_col1{
#             background-color:  #a00343;
#             color:  #f1f1f1;
#         }#T_94ea3_row3_col1,#T_94ea3_row8_col1,#T_94ea3_row11_col1,#T_94ea3_row12_col1{
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }#T_94ea3_row4_col1{
#             background-color:  #4d65ad;
#             color:  #f1f1f1;
#         }#T_94ea3_row5_col1{
#             background-color:  #5c51a3;
#             color:  #f1f1f1;
#         }#T_94ea3_row7_col1{
#             background-color:  #66c2a5;
#             color:  #000000;
#         }#T_94ea3_row9_col1{
#             background-color:  #cb334d;
#             color:  #f1f1f1;
#         }#T_94ea3_row10_col1{
#             background-color:  #f06744;
#             color:  #000000;
#         }#T_94ea3_row13_col1{
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }</style><table id="T_94ea3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >col_name</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >unique</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_94ea3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_94ea3_row0_col0" class="data row0 col0" >company</td>
#                         <td id="T_94ea3_row0_col1" class="data row0 col1" >8469</td>
#                         <td id="T_94ea3_row0_col2" class="data row0 col2" >['MM Media Pvt Ltd' 'find live infotech'
#  'Softtech Career Infosystem Pvt. Ltd' ...
#  'TeamLease Services Limited hiring for BPA Solution Architect'
#  'Austere Technology Solutions' 'Musk - Startup']</td>
#             </tr>
#             <tr>
#                         <th id="T_94ea3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_94ea3_row1_col0" class="data row1 col0" >education</td>
#                         <td id="T_94ea3_row1_col1" class="data row1 col1" >2355</td>
#                         <td id="T_94ea3_row1_col2" class="data row1 col2" >['UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate - Any Specialization, Post Graduation Not Required'
#  'UG: B.Tech/B.E. - Any Specialization PG:MBA/PGDM - Any Specialization'
#  'UG: Any Graduate - Any Specialization PG:Any Postgraduate Doctorate:Doctorate Not Required'
#  ... 'PG:MS/M.Sc(Science) - Any Specialization, Statistics'
#  'UG: B.Tech/B.E. - Any Specialization PG:MCA - Computers, M.Tech - Any Specialization, MS/M.Sc(Science) - Any Specialization Doctorate:Doctorate Not Required'
#  'UG: B.Tech/B.E. - Computers PG:MS/M.Sc(Science) - Computers Doctorate:Doctorate Not Required']</td>
#             </tr>
#             <tr>
#                         <th id="T_94ea3_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_94ea3_row2_col0" class="data row2 col0" >experience</td>
#                         <td id="T_94ea3_row2_col1" class="data row2 col1" >147</td>
#                         <td id="T_94ea3_row2_col2" class="data row2 col2" >['0 - 1 yrs' '0 - 0 yrs' '4 - 8 yrs' '11 - 15 yrs' '6 - 8 yrs' '2 - 5 yrs'
#  '1 - 3 yrs' '2 - 7 yrs' '1 - 5 yrs' '2 - 4 yrs' '3 - 8 yrs' '5 - 7 yrs'
#  '1 - 2 yrs' '5 - 10 yrs' '6 - 10 yrs' '10 - 12 yrs' '4 - 6 yrs'
#  '1 - 6 yrs' '3 - 6 yrs' '3 - 7 yrs' '4 - 9 yrs' '3 - 5 yrs' '0 - 5 yrs'
#  '5 - 8 yrs' '9 - 12 yrs' '7 - 12 yrs' '10 - 15 yrs' '4 - 7 yrs'
#  '8 - 12 yrs' '10 - 16 yrs' '5 - 9 yrs' '0 - 4 yrs' '10 - 20 yrs'
#  '10 - 18 yrs' '0 - 2 yrs' '7 - 10 yrs' '6 - 11 yrs' '2 - 3 yrs'
#  '1 - 4 yrs' '7 - 9 yrs' '8 - 13 yrs' '2 - 6 yrs' '8 - 10 yrs' '0 - 3 yrs'
#  '6 - 9 yrs' '15 - 20 yrs' '12 - 16 yrs' '1 - 1 yrs' '3 - 4 yrs'
#  '17 - 20 yrs' '10 - 17 yrs' '9 - 14 yrs' '13 - 15 yrs' '17 - 23 yrs'
#  '15 - 25 yrs' '14 - 22 yrs' '4 - 5 yrs' '7 - 11 yrs' '16 - 24 yrs'
#  '14 - 18 yrs' '12 - 15 yrs' '7 - 8 yrs' '5 - 6 yrs' '12 - 19 yrs'
#  '20 - 25 yrs' '10 - 13 yrs' '12 - 18 yrs' '6 - 7 yrs' '10 - 14 yrs'
#  '12 - 20 yrs' 'Not Mentioned' '11 - 16 yrs' '15 - 17 yrs' '20 - 30 yrs'
#  '15 - 21 yrs' '8 - 11 yrs' '8 - 9 yrs' '9 - 13 yrs' '15 - 22 yrs'
#  '14 - 19 yrs' '13 - 19 yrs' '15 - 16 yrs' '14 - 20 yrs' '11 - 12 yrs'
#  '1 - 8 yrs' '9 - 11 yrs' '15 - 18 yrs' '4 - 10 yrs' '10 - 11 yrs'
#  '12 - 22 yrs' '7 - 16 yrs' '16 - 18 yrs' '13 - 17 yrs' '13 - 20 yrs'
#  '5 - 5 yrs' '1 - 10 yrs' '12 - 14 yrs' '5 - 15 yrs' '11 - 17 yrs' nan
#  '16 - 20 yrs' '13 - 23 yrs' '3 - 3 yrs' '18 - 20 yrs' '23 - 30 yrs'
#  '14 - 24 yrs' '18 - 28 yrs' '11 - 21 yrs' '15 - 19 yrs' '18 - 22 yrs'
#  '6 - 12 yrs' '14 - 17 yrs' '12 - 17 yrs' '13 - 18 yrs' '25 - 30 yrs'
#  '11 - 14 yrs' '2 - 8 yrs' '2 - 10 yrs' '4 - 11 yrs' '11 - 13 yrs'
#  '14 - 16 yrs' '2 - 2 yrs' '10 - 19 yrs' '14 - 15 yrs' '2 - 9 yrs'
#  '13 - 16 yrs' '7 - 7 yrs' '9 - 10 yrs' '11 - 20 yrs' '12 - 13 yrs'
#  '15 - 24 yrs' '3 - -1 yrs' '10 - 10 yrs' '26 - 30 yrs' '7 - 14 yrs'
#  '11 - 19 yrs' '16 - 25 yrs' '11 - 18 yrs' '18 - 25 yrs' '17 - 25 yrs'
#  '18 - 21 yrs' '18 - 23 yrs' '20 - 24 yrs' '20 - 23 yrs' '3 - 10 yrs'
#  '17 - 27 yrs' '16 - 26 yrs' '13 - 22 yrs']</td>
#             </tr>
#             <tr>
#                         <th id="T_94ea3_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_94ea3_row3_col0" class="data row3 col0" >industry</td>
#                         <td id="T_94ea3_row3_col1" class="data row3 col1" >63</td>
#                         <td id="T_94ea3_row3_col2" class="data row3 col2" >['Media / Entertainment / Internet'
#  'Advertising / PR / MR / Event Management'
#  'IT-Software / Software Services'
#  'Banking / Financial Services / Broking' 'Aviation / Aerospace Firms'
#  'Industrial Products / Heavy Machinery' 'FMCG / Foods / Beverage'
#  'Recruitment / Staffing' 'Internet / Ecommerce'
#  'Travel / Hotels / Restaurants / Airlines / Railways'
#  'BPO / Call Centre / ITES' 'Pharma / Biotech / Clinical Research'
#  'Real Estate / Property' 'Insurance' 'Facility Management' 'Publishing'
#  'Education / Teaching / Training' 'Retail / Wholesale'
#  'Automobile / Auto Anciliary / Auto Components'
#  'Chemicals / PetroChemical / Plastic / Rubber' 'Government / Defence'
#  'Accounting / Finance' 'Textiles / Garments / Accessories'
#  'Semiconductors / Electronics' 'Telecom/ISP'
#  'Medical / Healthcare / Hospitals' 'Legal'
#  'Courier / Transportation / Freight / Warehousing'
#  'NGO / Social Services / Regulators / Industry Associations' 'Other'
#  'Architecture / Interior Design' 'KPO / Research / Analytics'
#  'Construction / Engineering / Cement / Metals'
#  'Office Equipment / Automation'
#  'Consumer Electronics / Appliances / Durables' 'Iron and Steel'
#  'Strategy / Management Consulting Firms'
#  'Oil and Gas / Energy / Power / Infrastructure'
#  'IT-Hardware & Networking' 'Wellness / Fitness / Sports / Beauty'
#  'Agriculture / Dairy' 'Electricals / Switchgears'
#  'Security / Law Enforcement' 'Gems / Jewellery'
#  'Ceramics / Sanitary ware' 'Fresher / Trainee / Entry Level'
#  'Food Processing' 'Printing / Packaging' 'Brewery / Distillery'
#  'Telecom/ISP /' 'Export / Import' 'Heat Ventilation / Air Conditioning'
#  'Wellness / Fitness / Sports' 'Water Treatment / Waste Management' nan
#  'Shipping / Marine' 'Glass / Glassware' 'Animation / Gaming'
#  'Fertilizers / Pesticides' 'Pulp and Paper' 'Tyres' 'Leather'
#  'Broadcasting' 'Medical Devices / Equipments']</td>
#             </tr>
#             <tr>
#                         <th id="T_94ea3_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_94ea3_row4_col0" class="data row4 col0" >jobdescription</td>
#                         <td id="T_94ea3_row4_col1" class="data row4 col1" >21063</td>
#                         <td id="T_94ea3_row4_col2" class="data row4 col2" >['Job Description \xa0 Send me Jobs like this Qualifications: - == > 10th To Graduation & Any Skill: - == >

# %% [markdown]
# 1. Clean payrate feature and featurize it.

# %%
df['payrate'].head(20)
# Out:
# 0                               1,50,000 - 2,25,000 P.A
# 1                        1,50,000 - 2,50,000 P.A. 20000
# 2                            Not Disclosed by Recruiter
# 3                            Not Disclosed by Recruiter
# 4                            Not Disclosed by Recruiter
# 5                            Not Disclosed by Recruiter
# 6                               3,00,000 - 6,50,000 P.A
# 7                            Not Disclosed by Recruiter
# 8                               1,00,000 - 2,00,000 P.A
# 9                            Not Disclosed by Recruiter
# 10                           Not Disclosed by Recruiter
# 11                           Not Disclosed by Recruiter
# 12                              1,75,000 - 2,50,000 P.A
# 13                           Not Disclosed by Recruiter
# 14                           Not Disclosed by Recruiter
# 15                           Not Disclosed by Recruiter
# 16    1,00,000 - 2,00,000 P.A. incentives for achiev...
# 17                              1,00,000 - 5,00,000 P.A
# 18                           Not Disclosed by Recruiter
# 19                           Not Disclosed by Recruiter
# Name: payrate, dtype: object

# %%
df['payrate'][0].split('-')[0]
# Out:
# '1,50,000 '

# %%
df['payrate'][0].split('-')[1]
# Out:
# ' 2,25,000 P.A'

# %%
len_pay=[]
for pay in df['payrate']:
    len_pay.append(len(str(pay).split('-')))

# %%
pd.Series(len_pay).value_counts()
# Out:
# 1    17028
# 2     4682
# 4      126
# 3       83
# 5       54
# 6       24
# 7        3
# dtype: int64

# %%
payrate_split=df['payrate'].str.split('-',expand=True)

# %%
payrate_split
# Out:
#                                 0                     1     2     3     4  \
# 0                       1,50,000           2,25,000 P.A  None  None  None
# 1                       1,50,000    2,50,000 P.A. 20000  None  None  None
# 2      Not Disclosed by Recruiter                  None  None  None  None
# 3      Not Disclosed by Recruiter                  None  None  None  None
# 4      Not Disclosed by Recruiter                  None  None  None  None
# ...                           ...                   ...   ...   ...   ...
# 21995  Not Disclosed by Recruiter                  None  None  None  None
# 21996                   8,50,000          14,00,000 P.A  None  None  None
# 21997  Not Disclosed by Recruiter                  None  None  None  None
# 21998  Not Disclosed by Recruiter                  None  None  None  None
# 21999                  12,00,000          22,00,000 P.A  None  None  None
#
#           5     6
# 0      None  None
# 1      None  None
# 2      None  None
# 3      None  None
# 4      None  None
# ...     ...   ...
# 21995  None  None
# 21996  None  None
# 21997  None  None
# 21998  None  None
# 21999  None  None
#
# [22000 rows x 7 columns]

# %%
payrate_split[0][0]
# Out:
# '1,50,000 '

# %%
payrate_split[0]=payrate_split[0].str.strip()

# %%
payrate_split[0].str.replace(',','')
# Out:
# 0                            150000
# 1                            150000
# 2        Not Disclosed by Recruiter
# 3        Not Disclosed by Recruiter
# 4        Not Disclosed by Recruiter
#                     ...
# 21995    Not Disclosed by Recruiter
# 21996                        850000
# 21997    Not Disclosed by Recruiter
# 21998    Not Disclosed by Recruiter
# 21999                       1200000
# Name: 0, Length: 22000, dtype: object

# %%
payrate_split[0]=payrate_split[0].apply(lambda x:str(x).replace(',',''))

# %%
payrate_split[0]
# Out:
# 0                            150000
# 1                            150000
# 2        Not Disclosed by Recruiter
# 3        Not Disclosed by Recruiter
# 4        Not Disclosed by Recruiter
#                     ...
# 21995    Not Disclosed by Recruiter
# 21996                        850000
# 21997    Not Disclosed by Recruiter
# 21998    Not Disclosed by Recruiter
# 21999                       1200000
# Name: 0, Length: 22000, dtype: object

# %%
pay=[]
for payrate in payrate_split[0]:
    try:
        if type(float(payrate))==np.float:
            pay.append(payrate)
    except:
            pay.append('missing value')
# Out:
# <ipython-input-28-b176a8f335a5>:4: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if type(float(payrate))==np.float:

# %%
pay
# Out:
# ['150000',
#  '150000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  '50000',
#  '900000',
#  'missing value',
#  'missing value',
#  '500000',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  '250000',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  '700000',
#  'missing value',
#  '600000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '125000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  '150000',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '800000',
#  '225000',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  '200000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  '150000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '150000',
#  'missing value',
#  '1200000',
#  '200000',
#  '500000',
#  '150000',
#  'missing value',
#  '300000',
#  'missing value',
#  '600000',
#  '250000',
#  'missing value',
#  '425000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  '500000',
#  'missing value',
#  '300000',
#  'missing value',
#  '150000',
#  'missing value',
#  'missing value',
#  '1400000',
#  '200000',
#  '100000',
#  '400000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '225000',
#  '500000',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  'missing value',
#  '175000',
#  '300000',
#  '200000',
#  '200000',
#  'missing value',
#  '700000',
#  '650000',
#  'missing value',
#  'missing value',
#  '500000',
#  'missing value',
#  '175000',
#  '600000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  '200000',
#  '200000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '150000',
#  '200000',
#  'missing value',
#  '175000',
#  '700000',
#  '500000',
#  '600000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '125000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '500000',
#  '1000000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '650000',
#  '300000',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  '650000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  '600000',
#  'missing value',
#  '500000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  '175000',
#  '225000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '1200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '225000',
#  'missing value',
#  'missing value',
#  '65000',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '750000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '3000000',
#  'missing value',
#  '600000',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  'missing value',
#  '350000',
#  '300000',
#  '400000',
#  '200000',
#  '550000',
#  'missing value',
#  '200000',
#  'missing value',
#  '200000',
#  '800000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  '100000',
#  '200000',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '225000',
#  'missing value',
#  '250000',
#  'missing value',
#  '400000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  '300000',
#  '2000000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '450000',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '80000',
#  '300000',
#  'missing value',
#  '600000',
#  '350000',
#  'missing value',
#  'missing value',
#  '600000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '325000',
#  'missing value',
#  'missing value',
#  '150000',
#  '400000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '1500000',
#  'missing value',
#  '100000',
#  'missing value',
#  '2000000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '1200000',
#  'missing value',
#  'missing value',
#  '225000',
#  'missing value',
#  '175000',
#  'missing value',
#  '150000',
#  '500000',
#  'missing value',
#  '200000',
#  '1000000',
#  'missing value',
#  '350000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '125000',
#  '50000',
#  'missing value',
#  '125000',
#  '350000',
#  'missing value',
#  '375000',
#  '350000',
#  'missing value',
#  '200000',
#  '175000',
#  '550000',
#  'missing value',
#  'missing value',
#  '225000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '500000',
#  'missing value',
#  '500000',
#  'missing value',
#  '325000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '325000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '2000000',
#  '200000',
#  'missing value',
#  '600000',
#  '3500000',
#  '300000',
#  '300000',
#  'missing value',
#  '1000000',
#  'missing value',
#  'missing value',
#  '200000',
#  '300000',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '500000',
#  'missing value',
#  '600000',
#  '450000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '2000000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  '200000',
#  'missing value',
#  '125000',
#  'missing value',
#  '325000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '200000',
#  '600000',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '60000',
#  '175000',
#  '200000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '900000',
#  'missing value',
#  '90000',
#  '1100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '150000',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  '300000',
#  '1000000',
#  'missing value',
#  '800000',
#  'missing value',
#  '150000',
#  'missing value',
#  '200000',
#  'missing value',
#  '2000000',
#  'missing value',
#  'missing value',
#  '700000',
#  'missing value',
#  '100000',
#  '125000',
#  '200000',
#  'missing value',
#  '2000000',
#  '200000',
#  '300000',
#  '600000',
#  'missing value',
#  '200000',
#  'missing value',
#  '200000',
#  'missing value',
#  '125000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '2000000',
#  '200000',
#  'missing value',
#  '200000',
#  '225000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '80000',
#  '2000000',
#  'missing value',
#  '300000',
#  '2000000',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  '700000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  '900000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  '200000',
#  '300000',
#  'missing value',
#  '275000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  '500000',
#  '50000',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  '350000',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  '200000',
#  '100000',
#  'missing value',
#  '300000',
#  'missing value',
#  '175000',
#  '400000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  'missing value',
#  '325000',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  '600000',
#  'missing value',
#  '500000',
#  'missing value',
#  '1300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '800000',
#  'missing value',
#  '300000',
#  '600000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '450000',
#  'missing value',
#  'missing value',
#  '200000',
#  '300000',
#  'missing value',
#  '300000',
#  '200000',
#  '400000',
#  'missing value',
#  '275000',
#  '275000',
#  'missing value',
#  '900000',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '150000',
#  '200000',
#  '300000',
#  '700000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  '700000',
#  '500000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '800000',
#  'missing value',
#  'missing value',
#  '200000',
#  '275000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '175000',
#  '400000',
#  'missing value',
#  '200000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '900000',
#  'missing value',
#  '150000',
#  '400000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '225000',
#  'missing value',
#  '2000000',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '500000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '300000',
#  'missing value',
#  'missing value',
#  '250000',
#  'missing value',
#  '275000',
#  'missing value',
#  'missing value',
#  '175000',
#  'missing value',
#  '100000',
#  '600000',
#  '400000',
#  'missing value',
#  'missing value',
#  '350000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '300000',
#  'missing value',
#  '300000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '450000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '1000000',
#  '700000',
#  '200000',
#  '450000',
#  'missing value',
#  '325000',
#  '300000',
#  '500000',
#  '250000',
#  '175000',
#  'missing value',
#  '125000',
#  '200000',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  '200000',
#  '300000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '300000',
#  '125000',
#  'missing value',
#  '100000',
#  '200000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  '175000',
#  '175000',
#  '750000',
#  'missing value',
#  'missing value',
#  '700000',
#  '225000',
#  'missing value',
#  'missing value',
#  '200000',
#  '1600000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  '150000',
#  '225000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '50000',
#  'missing value',
#  '400000',
#  '150000',
#  'missing value',
#  '50000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '225000',
#  '300000',
#  '250000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '325000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '700000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '275000',
#  'missing value',
#  '300000',
#  '400000',
#  '275000',
#  '225000',
#  'missing value',
#  '200000',
#  'missing value',
#  '2000000',
#  '225000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '100000',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  'missing value',
#  '250000',
#  '1200000',
#  '200000',
#  'missing value',
#  'missing value',
#  'missing value',
#  '400000',
#  'missing value',
#  ...]

# %%
pd.to_numeric(payrate_split[0],errors='coerce')
# Out:
# 0         150000.0
# 1         150000.0
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 21995          NaN
# 21996     850000.0
# 21997          NaN
# 21998          NaN
# 21999    1200000.0
# Name: 0, Length: 22000, dtype: float64

# %%
pattern='\D.*'

# %%
payrate_split[0].str.replace(pattern, '')
# Out:
# <ipython-input-32-3ddca34f8416>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   payrate_split[0].str.replace(pattern, '')
# 0         150000
# 1         150000
# 2
# 3
# 4
#           ...
# 21995
# 21996     850000
# 21997
# 21998
# 21999    1200000
# Name: 0, Length: 22000, dtype: object

# %%
any(map(str.isdigit,payrate_split[0]))
# Out:
# True

# %%
any(map(str.isnumeric,payrate_split[0]))
# Out:
# True

# %%
payrate_split[1][0]
# Out:
# ' 2,25,000 P.A'

# %%
payrate_split[1]=payrate_split[1].str.strip()

# %%
payrate_split[1]=payrate_split[1].apply(lambda x:str(x).replace(',',''))

# %%
payrate_split[1]=payrate_split[1].str.replace(pattern, '')
# Out:
# <ipython-input-38-32c666bf9152>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   payrate_split[1]=payrate_split[1].str.replace(pattern, '')

# %%
payrate_split[1]
# Out:
# 0         225000
# 1         250000
# 2
# 3
# 4
#           ...
# 21995
# 21996    1400000
# 21997
# 21998
# 21999    2200000
# Name: 1, Length: 22000, dtype: object

# %%
payrate_split.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# dtype: object

# %%
payrate_split[0]=pd.to_numeric(payrate_split[0],errors='coerce')
payrate_split[1]=pd.to_numeric(payrate_split[1],errors='coerce')

# %%
payrate_split.dtypes
# Out:
# 0    float64
# 1    float64
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# dtype: object

# %%
df['min_pay']=payrate_split[0]
df['max_pay']=payrate_split[1]

# %%
df.head(8)
# Out:
#                                              company  \
# 0                                   MM Media Pvt Ltd
# 1                                 find live infotech
# 2                Softtech Career Infosystem Pvt. Ltd
# 3                             Onboard HRServices LLP
# 4         Spire Technologies and Solutions Pvt. Ltd.
# 5                    PFS Web Global Services Pvt Ltd
# 6             Kinesis Management Consultant Pvt. Ltd
# 7  Agile HR consultancy Pvt. Ltd. hiring for Ross...
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# 5  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...    2 - 5 yrs
# 6                                                NaN    1 - 3 yrs
# 7  UG: Diploma - Any Specialization, Electrical, ...    2 - 7 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
# 5           IT-Software / Software Services
# 6           IT-Software / Software Services
# 7                Aviation / Aerospace Firms
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
# 5  Job Description   Send me Jobs like this We ar...  131016005070
# 6  Job Description   Send me Jobs like this exper...  131016004451
# 7  Job Description   Send me Jobs like this Job D...  121016002995
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
# 5                                          Bengaluru
# 6  Delhi NCR, Mumbai, Bengaluru, Kochi, Greater N...
# 7                                          Bengaluru
#
#                                             jobtitle  numberofpositions  \
# 0           Walkin Data Entry Operator (night Shift)                NaN
# 1                 Work Based Onhome Based Part Time.               60.0
# 2                             Pl/sql Developer - SQL                NaN
# 3             Manager/ad/partner - Indirect Tax - CA                NaN
# 4                    JAVA Technical Lead (6-8 yrs) -                4.0
# 5  WALK IN - As400 Developer - Pfsweb Global Serv...                NaN
# 6                                      PHP Developer                2.0
# 7  Member Technical Staff-wire Harness/cable Harn...               20.0
#
#                           payrate                   postdate site_name  \
# 0         1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000       NaN
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 3      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 4      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 5      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 6         3,00,000 - 6,50,000 P.A  2016-10-13 16:20:55 +0000       NaN
# 7      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
#
#                                   skills                           uniq_id  \
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae
# 4  IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4
# 5  IT Software - Application Programming  8c3af9062ea835b0965779e2c7faac76
# 6  IT Software - Application Programming  98f84958cd6409386e7f0c9e447b8510
# 7                             Production  c811c10568fdbfdb3d5e633c99c914b4
#
#     min_pay   max_pay
# 0  150000.0  225000.0
# 1  150000.0  250000.0
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
# 5       NaN       NaN
# 6  300000.0  650000.0
# 7       NaN       NaN

# %%
pay=pd.concat([payrate_split[0],payrate_split[1]],axis=1,sort=False)

# %%
pay.columns=['min_pay', 'max_pay']

# %%
pay
# Out:
#          min_pay    max_pay
# 0       150000.0   225000.0
# 1       150000.0   250000.0
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
# ...          ...        ...
# 21995        NaN        NaN
# 21996   850000.0  1400000.0
# 21997        NaN        NaN
# 21998        NaN        NaN
# 21999  1200000.0  2200000.0
#
# [22000 rows x 2 columns]

# %%
pd.concat([df,pay],axis=1,sort=False)
# Out:
#                                                 company  \
# 0                                      MM Media Pvt Ltd
# 1                                    find live infotech
# 2                   Softtech Career Infosystem Pvt. Ltd
# 3                                Onboard HRServices LLP
# 4            Spire Technologies and Solutions Pvt. Ltd.
# ...                                                 ...
# 21995       Morgan Stanley Advantage Services Pvt. Ltd.
# 21996  Careernet Technologies Pvt Ltd hiring for Client
# 21997                                    Musk - Startup
# 21998                                      Confidential
# 21999                   Cambio Consulting India Pvt Ltd
#
#                                                education   experience  \
# 0      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1      UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2      UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3      UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# ...                                                  ...          ...
# 21995              UG: Any Graduate - Any Specialization   9 - 13 yrs
# 21996  UG: B.Tech/B.E. - Any Specialization PG:M.Tech...    3 - 5 yrs
# 21997  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    2 - 4 yrs
# 21998  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   7 - 12 yrs
# 21999  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   5 - 10 yrs
#
#                                        industry  \
# 0              Media / Entertainment / Internet
# 1      Advertising / PR / MR / Event Management
# 2               IT-Software / Software Services
# 3        Banking / Financial Services / Broking
# 4               IT-Software / Software Services
# ...                                         ...
# 21995    Banking / Financial Services / Broking
# 21996           IT-Software / Software Services
# 21997                      Internet / Ecommerce
# 21998           IT-Software / Software Services
# 21999           IT-Software / Software Services
#
#                                           jobdescription         jobid  \
# 0      Job Description   Send me Jobs like this Quali...  210516002263
# 1      Job Description   Send me Jobs like this Quali...  210516002391
# 2      Job Description   Send me Jobs like this - as ...  101016900534
# 3      Job Description   Send me Jobs like this - Inv...   81016900536
# 4      Job Description   Send me Jobs like this Pleas...  120916002122
# ...                                                  ...           ...
# 21995  Job Description   Send me Jobs like this Greet...  241116007152
# 21996  Job Description   Send me Jobs like this Looki...  241116001104
# 21997  Job Description   Send me Jobs like this Work ...  251116900644
# 21998  Job Description   Send me Jobs like this We ar...  231116901329
# 21999  Job Description   Send me Jobs like this Job d...  251116003840
#
#                                      joblocation_address  \
# 0                                                Chennai
# 1                                                Chennai
# 2                                              Bengaluru
# 3      Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                              Bengaluru
# ...                                                  ...
# 21995                                          Bengaluru
# 21996                                 Bengaluru, Gurgaon
# 21997                                          Bengaluru
# 21998                               Delhi NCR, Bengaluru
# 21999                                          Bengaluru
#
#                                                 jobtitle  numberofpositions  \
# 0               Walkin Data Entry Operator (night Shift)                NaN
# 1                     Work Based Onhome Based Part Time.               60.0
# 2                                 Pl/sql Developer - SQL                NaN
# 3                 Manager/ad/partner - Indirect Tax - CA                NaN
# 4                        JAVA Technical Lead (6-8 yrs) -                4.0
# ...                                                  ...                ...
# 21995  Quality Assurance - VP with Morgan Stanley Ban...                2.0
# 21996      Java Backend Developers for a Product Company                NaN
# 21997                    Full Stack Development Engineer                NaN
# 21998  Sr UI Developer/ Technical Lead - Html/ CSS/ J...                NaN
# 21999                              RF Firmware Engineers                NaN
#
#                               payrate                   postdate  \
# 0             1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000
# 1      1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000
# 2          Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 3          Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# 4          Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000
# ...                               ...                        ...
# 21995      Not Disclosed by Recruiter  2016-11-25 22:47:05 +0000
# 21996        8,50,000 - 14,00,000 P.A  2016-11-24 22:47:05 +0000
# 21997      Not Disclosed by Recruiter  2016-11-25 22:47:05 +0000
# 21998      Not Disclosed by Recruiter  2016-11-27 22:47:05 +0000
# 21999       12,00,000 - 22,00,000 P.A  2016-11-25 22:47:05 +0000
#
#             site_name                                 skills  \
# 0                 NaN                                   ITES
# 1                 NaN                              Marketing
# 2                 NaN  IT Software - Application Programming
# 3                 NaN                               Accounts
# 4                 NaN  IT Software - Application Programming
# ...               ...                                    ...
# 21995  www.naukri.com             IT Software - QA & Testing
# 21996  www.naukri.com  IT Software - Application Programming
# 21997  www.naukri.com  IT Software - Application Programming
# 21998  www.naukri.com  IT Software - Application Programming
# 21999  www.naukri.com       IT Software - System Programming
#
#                                 uniq_id    min_pay    max_pay    min_pay  \
# 0      43b19632647068535437c774b6ca6cf8   150000.0   225000.0   150000.0
# 1      d4c72325e57f89f364812b5ed5a795f0   150000.0   250000.0   150000.0
# 2      c47df6f4cfdf5b46f1fd713ba61b9eba        NaN        NaN        NaN
# 3      115d28f140f694dd1cc61c53d03c66ae        NaN        NaN        NaN
# 4      a12553fc03bc7bcced8b1bb8963f97b4        NaN        NaN        NaN
# ...                                 ...        ...        ...        ...
# 21995  ef40136e3b0c0abdab695d979a4b7153        NaN        NaN        NaN
# 21996  acb80b7bb109fa76d22d1f11c6e16c6a   850000.0  1400000.0   850000.0
# 21997  f6f2885a6c87572616fb766029a0d284        NaN        NaN        NaN
# 21998  c6f6538cb1007dd02c1b4b77909b3d38        NaN        NaN        NaN
# 21999  74fec26df6e1c0be0171311a2f03f180  1200000.0  2200000.0  1200000.0
#
#          max_pay
# 0       225000.0
# 1       250000.0
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 21995        NaN
# 21996  1400000.0
# 21997        NaN
# 21998        NaN
# 21999  2200000.0
#
# [22000 rows x 18 columns]

# %% [markdown]
# 1. Perform Data Cleaning and Featuerization on experience feature

# %%
df['experience'][0]
# Out:
# '0 - 1 yrs'

# %%
value='0-1yrs'

# %%
value.split('-')[0]
# Out:
# '0'

# %%
value.split('-')[1]
# Out:
# '1yrs'

# %%
def split_exp(exp):
    min_exp=exp.split('-')[0]
    max_exp=exp.split('-')[1]
    return min_exp, max_exp

# %%
split_exp(value)
# Out:
# ('0', '1yrs')

# %%
df['experience'].apply(split_exp)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-3d3aae19a6a6> in <module>
# ----> 1 df['experience'].apply(split_exp)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-53-fe0adee9968d> in split_exp(exp)
#       1 def split_exp(exp):
#       2     min_exp=exp.split('-')[0]
# ----> 3     max_exp=exp.split('-')[1]
#       4     return min_exp, max_exp
#
# IndexError: list index out of range

# %%
len1=[]
for exp in df['experience'].dropna():
    if len(exp.split('-'))!=2:
        len1.append(exp)

# %%
len1
# Out:
# ['Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  '3 - -1 yrs',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned',
#  'Not Mentioned']

# %%
def split_exp2(exp):
    try:
        if len(exp.split('-'))==2:
            min_exp=exp.split('-')[0]
            max_exp=exp.split('-')[1]
        return pd.Series([min_exp, max_exp])
    except:
        return pd.Series([np.nan,np.nan])

# %%
df[['min_exp','max_exp']]=df['experience'].apply(split_exp2).rename(columns={0:'min_exp',1:'max_exp'})

# %%
nm=pd.DataFrame(df['experience'].str.contains('Not Mentioned'))

# %%
nm[nm['experience']==True].index
# Out:
# Int64Index([ 1138,  5167,  7193,  7195,  7206,  7296,  7385,  7452,  7467,
#              7555,
#             ...
#             12988, 12998, 14404, 20342, 20562, 21295, 21315, 21397, 21430,
#             21584],
#            dtype='int64', length=111)

# %%
df['experience'][1138]
# Out:
# 'Not Mentioned'

# %%
split_exp2(df['experience'][1138])
# Out:
# 0   NaN
# 1   NaN
# dtype: float64

# %%
df['max_exp']=df['max_exp'].str.replace('yrs','')

# %%
df.head(3)
# Out:
#                                company  \
# 0                     MM Media Pvt Ltd
# 1                   find live infotech
# 2  Softtech Career Infosystem Pvt. Ltd
#
#                                            education experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...  0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...  0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...  4 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
#
#   joblocation_address                                  jobtitle  \
# 0             Chennai  Walkin Data Entry Operator (night Shift)
# 1             Chennai        Work Based Onhome Based Part Time.
# 2           Bengaluru                    Pl/sql Developer - SQL
#
#    numberofpositions                         payrate  \
# 0                NaN         1,50,000 - 2,25,000 P.A
# 1               60.0  1,50,000 - 2,50,000 P.A. 20000
# 2                NaN      Not Disclosed by Recruiter
#
#                     postdate site_name                                 skills  \
# 0  2016-05-21 19:30:00 +0000       NaN                                   ITES
# 1  2016-05-21 19:30:00 +0000       NaN                              Marketing
# 2  2016-10-13 16:20:55 +0000       NaN  IT Software - Application Programming
#
#                             uniq_id   min_pay   max_pay min_exp max_exp
# 0  43b19632647068535437c774b6ca6cf8  150000.0  225000.0      0       1
# 1  d4c72325e57f89f364812b5ed5a795f0  150000.0  250000.0      0       0
# 2  c47df6f4cfdf5b46f1fd713ba61b9eba       NaN       NaN      4       8

# %%
df.dtypes
# Out:
# company                 object
# education               object
# experience              object
# industry                object
# jobdescription          object
# jobid                    int64
# joblocation_address     object
# jobtitle                object
# numberofpositions      float64
# payrate                 object
# postdate                object
# site_name               object
# skills                  object
# uniq_id                 object
# min_pay                float64
# max_pay                float64
# min_exp                 object
# max_exp                 object
# dtype: object

# %%
df['min_exp']=df['min_exp'].astype(float)
df['max_exp']=df['max_exp'].astype(float)

# %%
df.dtypes
# Out:
# company                 object
# education               object
# experience              object
# industry                object
# jobdescription          object
# jobid                    int64
# joblocation_address     object
# jobtitle                object
# numberofpositions      float64
# payrate                 object
# postdate                object
# site_name               object
# skills                  object
# uniq_id                 object
# min_pay                float64
# max_pay                float64
# min_exp                float64
# max_exp                float64
# dtype: object

# %%
df['avg_experience']=(df['min_exp']+df['max_exp'])/2
df['avg_payrate']=(df['min_pay']+df['max_pay'])/2

# %%
df.head()
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
#
#                                    jobtitle  numberofpositions  \
# 0  Walkin Data Entry Operator (night Shift)                NaN
# 1        Work Based Onhome Based Part Time.               60.0
# 2                    Pl/sql Developer - SQL                NaN
# 3    Manager/ad/partner - Indirect Tax - CA                NaN
# 4           JAVA Technical Lead (6-8 yrs) -                4.0
#
#                           payrate                   postdate site_name  \
# 0         1,50,000 - 2,25,000 P.A  2016-05-21 19:30:00 +0000       NaN
# 1  1,50,000 - 2,50,000 P.A. 20000  2016-05-21 19:30:00 +0000       NaN
# 2      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 3      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
# 4      Not Disclosed by Recruiter  2016-10-13 16:20:55 +0000       NaN
#
#                                   skills                           uniq_id  \
# 0                                   ITES  43b19632647068535437c774b6ca6cf8
# 1                              Marketing  d4c72325e57f89f364812b5ed5a795f0
# 2  IT Software - Application Programming  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3                               Accounts  115d28f140f694dd1cc61c53d03c66ae
# 4  IT Software - Application Programming  a12553fc03bc7bcced8b1bb8963f97b4
#
#     min_pay   max_pay  min_exp  max_exp  avg_experience  avg_payrate
# 0  150000.0  225000.0      0.0      1.0             0.5     187500.0
# 1  150000.0  250000.0      0.0      0.0             0.0     200000.0
# 2       NaN       NaN      4.0      8.0             6.0          NaN
# 3       NaN       NaN     11.0     15.0            13.0          NaN
# 4       NaN       NaN      6.0      8.0             7.0          NaN

# %% [markdown]
# 1. Perform feature engineering on postdate variable

# %%
np.dtype('datetime64[ns]')==np.dtype('<M8[ns]')
# Out:
# True

# %%
df['payrate'].dtype
# Out:
# dtype('O')

# %%
def fetch_dt_att(dataframe,feature):
    try:
        return pd.Series([dataframe[feature].dt.day,dataframe[feature].dt.month,dataframe[feature].dt.year])
    except:
        print('Data-type is not supported')

# %%
fetch_dt_att(df,'postdate')
# Out:
# Data-type is not supported

# %%
df['postdate']=pd.to_datetime(df['postdate'])

# %%
df['postdate'].dtype
# Out:
# datetime64[ns, UTC]

# %%
df[['day','month','year']]=fetch_dt_att(df,'postdate')

# %%
df.head()
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
#                                       jobdescription         jobid  \
# 0  Job Description   Send me Jobs like this Quali...  210516002263
# 1  Job Description   Send me Jobs like this Quali...  210516002391
# 2  Job Description   Send me Jobs like this - as ...  101016900534
# 3  Job Description   Send me Jobs like this - Inv...   81016900536
# 4  Job Description   Send me Jobs like this Pleas...  120916002122
#
#                                  joblocation_address  \
# 0                                            Chennai
# 1                                            Chennai
# 2                                          Bengaluru
# 3  Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                          Bengaluru
#
#                                    jobtitle  numberofpositions  \
# 0  Walkin Data Entry Operator (night Shift)                NaN
# 1        Work Based Onhome Based Part Time.               60.0
# 2                    Pl/sql Developer - SQL                NaN
# 3    Manager/ad/partner - Indirect Tax - CA                NaN
# 4           JAVA Technical Lead (6-8 yrs) -                4.0
#
#                           payrate  ...                           uniq_id  \
# 0         1,50,000 - 2,25,000 P.A  ...  43b19632647068535437c774b6ca6cf8
# 1  1,50,000 - 2,50,000 P.A. 20000  ...  d4c72325e57f89f364812b5ed5a795f0
# 2      Not Disclosed by Recruiter  ...  c47df6f4cfdf5b46f1fd713ba61b9eba
# 3      Not Disclosed by Recruiter  ...  115d28f140f694dd1cc61c53d03c66ae
# 4      Not Disclosed by Recruiter  ...  a12553fc03bc7bcced8b1bb8963f97b4
#
#     min_pay   max_pay min_exp  max_exp  avg_experience  avg_payrate   day  \
# 0  150000.0  225000.0     0.0      1.0             0.5     187500.0  21.0
# 1  150000.0  250000.0     0.0      0.0             0.0     200000.0  21.0
# 2       NaN       NaN     4.0      8.0             6.0          NaN  13.0
# 3       NaN       NaN    11.0     15.0            13.0          NaN  13.0
# 4       NaN       NaN     6.0      8.0             7.0          NaN  13.0
#
#    month    year
# 0    5.0  2016.0
# 1    5.0  2016.0
# 2   10.0  2016.0
# 3   10.0  2016.0
# 4   10.0  2016.0
#
# [5 rows x 23 columns]

# %%
def fetch_dt_att2(x):
    return ([x.day,x.month,x.year])

# %%
fe_date=pd.DataFrame(map(fetch_dt_att2,df['postdate'])).rename(columns={0:'day',1:'month',2:'year'})

# %%
fe_date
# Out:
#         day  month    year
# 0      21.0    5.0  2016.0
# 1      21.0    5.0  2016.0
# 2      13.0   10.0  2016.0
# 3      13.0   10.0  2016.0
# 4      13.0   10.0  2016.0
# ...     ...    ...     ...
# 21995  25.0   11.0  2016.0
# 21996  24.0   11.0  2016.0
# 21997  25.0   11.0  2016.0
# 21998  27.0   11.0  2016.0
# 21999  25.0   11.0  2016.0
#
# [22000 rows x 3 columns]

# %%
pd.concat([df,fe_date],axis=1)
# Out:
#                                                 company  \
# 0                                      MM Media Pvt Ltd
# 1                                    find live infotech
# 2                   Softtech Career Infosystem Pvt. Ltd
# 3                                Onboard HRServices LLP
# 4            Spire Technologies and Solutions Pvt. Ltd.
# ...                                                 ...
# 21995       Morgan Stanley Advantage Services Pvt. Ltd.
# 21996  Careernet Technologies Pvt Ltd hiring for Client
# 21997                                    Musk - Startup
# 21998                                      Confidential
# 21999                   Cambio Consulting India Pvt Ltd
#
#                                                education   experience  \
# 0      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1      UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2      UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3      UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4      UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
# ...                                                  ...          ...
# 21995              UG: Any Graduate - Any Specialization   9 - 13 yrs
# 21996  UG: B.Tech/B.E. - Any Specialization PG:M.Tech...    3 - 5 yrs
# 21997  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    2 - 4 yrs
# 21998  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   7 - 12 yrs
# 21999  UG: B.Tech/B.E. - Any Specialization PG:MCA - ...   5 - 10 yrs
#
#                                        industry  \
# 0              Media / Entertainment / Internet
# 1      Advertising / PR / MR / Event Management
# 2               IT-Software / Software Services
# 3        Banking / Financial Services / Broking
# 4               IT-Software / Software Services
# ...                                         ...
# 21995    Banking / Financial Services / Broking
# 21996           IT-Software / Software Services
# 21997                      Internet / Ecommerce
# 21998           IT-Software / Software Services
# 21999           IT-Software / Software Services
#
#                                           jobdescription         jobid  \
# 0      Job Description   Send me Jobs like this Quali...  210516002263
# 1      Job Description   Send me Jobs like this Quali...  210516002391
# 2      Job Description   Send me Jobs like this - as ...  101016900534
# 3      Job Description   Send me Jobs like this - Inv...   81016900536
# 4      Job Description   Send me Jobs like this Pleas...  120916002122
# ...                                                  ...           ...
# 21995  Job Description   Send me Jobs like this Greet...  241116007152
# 21996  Job Description   Send me Jobs like this Looki...  241116001104
# 21997  Job Description   Send me Jobs like this Work ...  251116900644
# 21998  Job Description   Send me Jobs like this We ar...  231116901329
# 21999  Job Description   Send me Jobs like this Job d...  251116003840
#
#                                      joblocation_address  \
# 0                                                Chennai
# 1                                                Chennai
# 2                                              Bengaluru
# 3      Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                              Bengaluru
# ...                                                  ...
# 21995                                          Bengaluru
# 21996                                 Bengaluru, Gurgaon
# 21997                                          Bengaluru
# 21998                               Delhi NCR, Bengaluru
# 21999                                          Bengaluru
#
#                                                 jobtitle  numberofpositions  \
# 0               Walkin Data Entry Operator (night Shift)                NaN
# 1                     Work Based Onhome Based Part Time.               60.0
# 2                                 Pl/sql Developer - SQL                NaN
# 3                 Manager/ad/partner - Indirect Tax - CA                NaN
# 4                        JAVA Technical Lead (6-8 yrs) -                4.0
# ...                                                  ...                ...
# 21995  Quality Assurance - VP with Morgan Stanley Ban...                2.0
# 21996      Java Backend Developers for a Product Company                NaN
# 21997                    Full Stack Development Engineer                NaN
# 21998  Sr UI Developer/ Technical Lead - Html/ CSS/ J...                NaN
# 21999                              RF Firmware Engineers                NaN
#
#                               payrate  ... min_exp max_exp avg_experience  \
# 0             1,50,000 - 2,25,000 P.A  ...     0.0     1.0            0.5
# 1      1,50,000 - 2,50,000 P.A. 20000  ...     0.0     0.0            0.0
# 2          Not Disclosed by Recruiter  ...     4.0     8.0            6.0
# 3          Not Disclosed by Recruiter  ...    11.0    15.0           13.0
# 4          Not Disclosed by Recruiter  ...     6.0     8.0            7.0
# ...                               ...  ...     ...     ...            ...
# 21995      Not Disclosed by Recruiter  ...     9.0    13.0           11.0
# 21996        8,50,000 - 14,00,000 P.A  ...     3.0     5.0            4.0
# 21997      Not Disclosed by Recruiter  ...     2.0     4.0            3.0
# 21998      Not Disclosed by Recruiter  ...     7.0    12.0            9.5
# 21999       12,00,000 - 22,00,000 P.A  ...     5.0    10.0            7.5
#
#       avg_payrate   day  month    year   day  month    year
# 0        187500.0  21.0    5.0  2016.0  21.0    5.0  2016.0
# 1        200000.0  21.0    5.0  2016.0  21.0    5.0  2016.0
# 2             NaN  13.0   10.0  2016.0  13.0   10.0  2016.0
# 3             NaN  13.0   10.0  2016.0  13.0   10.0  2016.0
# 4             NaN  13.0   10.0  2016.0  13.0   10.0  2016.0
# ...           ...   ...    ...     ...   ...    ...     ...
# 21995         NaN  25.0   11.0  2016.0  25.0   11.0  2016.0
# 21996   1125000.0  24.0   11.0  2016.0  24.0   11.0  2016.0
# 21997         NaN  25.0   11.0  2016.0  25.0   11.0  2016.0
# 21998         NaN  27.0   11.0  2016.0  27.0   11.0  2016.0
# 21999   1700000.0  25.0   11.0  2016.0  25.0   11.0  2016.0
#
# [22000 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id', 'min_pay',
#        'max_pay', 'min_exp', 'max_exp', 'avg_experience', 'avg_payrate', 'day',
#        'month', 'year'],
#       dtype='object')

# %%
df['joblocation_address']
# Out:
# 0                                                  Chennai
# 1                                                  Chennai
# 2                                                Bengaluru
# 3        Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 4                                                Bengaluru
#                                ...
# 21995                                            Bengaluru
# 21996                                   Bengaluru, Gurgaon
# 21997                                            Bengaluru
# 21998                                 Delhi NCR, Bengaluru
# 21999                                            Bengaluru
# Name: joblocation_address, Length: 22000, dtype: object

# %%
df['joblocation_address'].value_counts().head(10)
# Out:
# Bengaluru/Bangalore         3775
# Mumbai                      2348
# Bengaluru                   1453
# Hyderabad / Secunderabad    1246
# Chennai                     1204
# Hyderabad                    936
# Noida                        775
# Delhi                        763
# Gurgaon                      743
# Mumbai , Mumbai              514
# Name: joblocation_address, dtype: int64

# %%
data=df.copy()

# %%
pd.Series(data['joblocation_address'].unique())
# Out:
# 0                                                 Chennai
# 1                                               Bengaluru
# 2       Mumbai, Bengaluru, Kolkata, Chennai, Coimbator...
# 3       Delhi NCR, Mumbai, Bengaluru, Kochi, Greater N...
# 4                                Mumbai, Delhi, Bengaluru
#                               ...
# 2325                           Mumbai, Bengaluru, Kolkata
# 2326                  Bengaluru, Pune, Chennai, Delhi NCR
# 2327                Mumbai, Bengaluru, Hyderabad, Kolkata
# 2328    Mumbai, Chennai, Delhi, Bengaluru, Hyderabad, ...
# 2329                                  Bengaluru, Malaysia
# Length: 2330, dtype: object

# %%
data['joblocation_address'].value_counts().head(60).index
# Out:
# Index(['Bengaluru/Bangalore', 'Mumbai', 'Bengaluru',
#        'Hyderabad / Secunderabad', 'Chennai', 'Hyderabad', 'Noida', 'Delhi',
#        'Gurgaon', 'Mumbai , Mumbai', 'Delhi/NCR(National Capital Region)',
#        'Bengaluru/Bangalore , Bengaluru / Bangalore', 'Delhi , Delhi',
#        'Noida , Noida/Greater Noida', 'Gurgaon , Gurgaon',
#        'Bengaluru/Bangalore , Chennai , Hyderabad / Secunderabad', 'Ghaziabad',
#        'Bengaluru/Bangalore , Hyderabad / Secunderabad',
#        'Bengaluru, Hyderabad', 'Delhi/NCR(National Capital Region) , Gurgaon',
#        'Bengaluru/Bangalore , Chennai',
#        'Bengaluru/Bangalore , Mumbai , Chennai , Pune , Hyderabad / Secunderabad , Delhi/NCR(National Capital Region) , Ahmedabad , Kolkata , Surat',
#        'Bengaluru/Bangalore , karnataka',
#        'Delhi , Delhi/NCR(National Capital Region)',
#        'Chennai , Hyderabad / Secunderabad',
#        'Hyderabad / Secunderabad , Hyderabad/Secunderabad',
#        'Delhi/NCR(National Capital Region) , Noida',
#        'Bengaluru, Chennai, Hyderabad', 'Navi Mumbai', 'Mumbai , mumbai',
#        'Mumbai , Navi Mumbai', 'Hyderabad, Bengaluru', 'Faridabad',
#        'Mumbai , Pune', 'Chennai , Bengaluru/Bangalore',
#        'Bengaluru, Hyderabad, Chennai', 'Bengaluru/Bangalore , Mumbai',
#        'Hyderabad / Secunderabad , Bengaluru/Bangalore', 'Mumbai, Bengaluru',
#        'Bengaluru/Bangalore , Chennai , Noida , Hyderabad / Secunderabad',
#        'Bengaluru/Bangalore , Mumbai , Chennai', 'Delhi , Mumbai',
#        'Bengaluru, Chennai',
#        'Bengaluru/Bangalore , Bengaluru / Bangalore , Delhi , Mumbai',
#        'Bengaluru/Bangalore , Mumbai , Delhi/NCR(National Capital Region)',
#        'Delhi , Delhi/NCR', 'Bengaluru Bangalore',
#        'Bengaluru/Bangalore , Hyderabad / Secunderabad , Delhi/NCR(National Capital Region)',
#        'Bengaluru/Bangalore , Gurgaon',
#        'Gurgaon , Delhi/NCR(National Capital Region)', 'Mumbai, maharashtra',
#        'Mumbai , Hyderabad / Secunderabad , Guwahati , Bhubaneshwar , Raipur , Chandigarh',
#        'Bengaluru/Bangalore , Bengaluru / Bangalore , Mumbai',
#        'Bengaluru/Bangalore , Bengaluru / Bangalore , Delhi',
#        'Bengaluru/Bangalore , bangalore',
#        'Delhi/NCR(National Capital Region) , Gurgaon , Noida',
#        'Delhi/NCR(National Capital Region) , Delhi',
#        'Noida , Bengaluru/Bangalore',
#        'Bengaluru/Bangalore , Bengaluru / Bangalore , Gurgaon',
#        'Bengaluru/Bangalore , Hyderabad / Secunderabad , Chennai'],
#       dtype='object')
